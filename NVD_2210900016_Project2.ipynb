-- %% [markdown]
-- # [dbo].[chitietdonhang]

-- %%
USE [NguyenVanDuoc_2210900016_Project2]
GO

-- %%
/****** Object:  Table [dbo].[chitietdonhang]    Script Date: 10/24/2024 8:07:18 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[chitietdonhang](
	[MaCTDH] [int] IDENTITY(1,1) NOT NULL,
	[MaDon] [int] NULL,
	[MaSP] [int] NULL,
	[SoLuong] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[MaCTDH] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[donhang]

-- %%
/****** Object:  Table [dbo].[donhang]    Script Date: 10/24/2024 8:07:18 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[donhang](
	[MaDon] [int] IDENTITY(1,1) NOT NULL,
	[Makhach] [int] NULL,
	[NgayDatHang] [datetime] NULL,
	[TongGiaTri] [decimal](10, 2) NULL,
	[ThanhToan] [bit] NULL,
PRIMARY KEY CLUSTERED 
(
	[MaDon] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[khachhang]

-- %%
/****** Object:  Table [dbo].[khachhang]    Script Date: 10/24/2024 8:07:18 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[khachhang](
	[MaKhach] [int] IDENTITY(1,1) NOT NULL,
	[HoTen] [nvarchar](50) NULL,
	[SDT] [nvarchar](20) NULL,
	[DiaChi] [nvarchar](225) NULL,
PRIMARY KEY CLUSTERED 
(
	[MaKhach] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[sanpham]

-- %%
/****** Object:  Table [dbo].[sanpham]    Script Date: 10/24/2024 8:07:18 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[sanpham](
	[MaSP] [int] IDENTITY(1,1) NOT NULL,
	[TenSP] [nvarchar](100) NULL,
	[DonGia] [decimal](10, 2) NULL,
	[SoLuong] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[MaSP] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[chitietdonhang]

-- %%
SET IDENTITY_INSERT [dbo].[chitietdonhang] ON 
INSERT [dbo].[chitietdonhang] ([MaCTDH], [MaDon], [MaSP], [SoLuong]) VALUES (1, 1, 1, 2)
INSERT [dbo].[chitietdonhang] ([MaCTDH], [MaDon], [MaSP], [SoLuong]) VALUES (2, 2, 2, 1)
INSERT [dbo].[chitietdonhang] ([MaCTDH], [MaDon], [MaSP], [SoLuong]) VALUES (3, 3, 3, 3)
SET IDENTITY_INSERT [dbo].[chitietdonhang] OFF
GO

-- %% [markdown]
-- # [dbo].[donhang]

-- %%
SET IDENTITY_INSERT [dbo].[donhang] ON 
INSERT [dbo].[donhang] ([MaDon], [Makhach], [NgayDatHang], [TongGiaTri], [ThanhToan]) VALUES (1, 1, CAST(N'2024-04-19T08:30:00.000' AS DateTime), CAST(50000000.00 AS Decimal(10, 2)), 1)
INSERT [dbo].[donhang] ([MaDon], [Makhach], [NgayDatHang], [TongGiaTri], [ThanhToan]) VALUES (2, 2, CAST(N'2024-04-18T10:45:00.000' AS DateTime), CAST(75000000.00 AS Decimal(10, 2)), 0)
INSERT [dbo].[donhang] ([MaDon], [Makhach], [NgayDatHang], [TongGiaTri], [ThanhToan]) VALUES (3, 3, CAST(N'2024-04-17T15:20:00.000' AS DateTime), CAST(30000000.00 AS Decimal(10, 2)), 1)
SET IDENTITY_INSERT [dbo].[donhang] OFF
GO

-- %% [markdown]
-- # [dbo].[khachhang]

-- %%
SET IDENTITY_INSERT [dbo].[khachhang] ON 
INSERT [dbo].[khachhang] ([MaKhach], [HoTen], [SDT], [DiaChi]) VALUES (1, N'Nguyễn Văn Nam', N'384889248', N'Hà Nội')
INSERT [dbo].[khachhang] ([MaKhach], [HoTen], [SDT], [DiaChi]) VALUES (2, N'Lương Thị Cúc', N'947385774', N'Hà Nam')
INSERT [dbo].[khachhang] ([MaKhach], [HoTen], [SDT], [DiaChi]) VALUES (3, N'Đinh Thị Bích Diệp', N'278544879', N'Lạng Sơn')
SET IDENTITY_INSERT [dbo].[khachhang] OFF
GO

-- %% [markdown]
-- # [dbo].[sanpham]

-- %%
SET IDENTITY_INSERT [dbo].[sanpham] ON 
INSERT [dbo].[sanpham] ([MaSP], [TenSP], [DonGia], [SoLuong]) VALUES (1, N'iPhone 14', CAST(24000000.00 AS Decimal(10, 2)), 24)
INSERT [dbo].[sanpham] ([MaSP], [TenSP], [DonGia], [SoLuong]) VALUES (2, N'SamSung Galaxy S23', CAST(22000000.00 AS Decimal(10, 2)), 15)
INSERT [dbo].[sanpham] ([MaSP], [TenSP], [DonGia], [SoLuong]) VALUES (3, N'Xiaomi Mi 13', CAST(15000000.00 AS Decimal(10, 2)), 20)
SET IDENTITY_INSERT [dbo].[sanpham] OFF
GO

-- %% [markdown]
-- # [FK_donhang_chitietdonhang]

-- %%
ALTER TABLE [dbo].[chitietdonhang]  WITH CHECK ADD  CONSTRAINT [FK_donhang_chitietdonhang] FOREIGN KEY([MaDon])
REFERENCES [dbo].[donhang] ([MaDon])
GO
ALTER TABLE [dbo].[chitietdonhang] CHECK CONSTRAINT [FK_donhang_chitietdonhang]
GO

-- %% [markdown]
-- # [FK_sanpham_chitietdonhang]

-- %%
ALTER TABLE [dbo].[chitietdonhang]  WITH CHECK ADD  CONSTRAINT [FK_sanpham_chitietdonhang] FOREIGN KEY([MaSP])
REFERENCES [dbo].[sanpham] ([MaSP])
GO
ALTER TABLE [dbo].[chitietdonhang] CHECK CONSTRAINT [FK_sanpham_chitietdonhang]
GO

-- %% [markdown]
-- # [FK_khachhang_donhang]

-- %%
ALTER TABLE [dbo].[donhang]  WITH CHECK ADD  CONSTRAINT [FK_khachhang_donhang] FOREIGN KEY([Makhach])
REFERENCES [dbo].[khachhang] ([MaKhach])
GO
ALTER TABLE [dbo].[donhang] CHECK CONSTRAINT [FK_khachhang_donhang]
GO
